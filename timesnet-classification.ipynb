# %% [markdown]
# # TimesNet anomaly classification in GPVS

# %% [markdown]
# ## Clone repo

# %%
# !git clone https://github.com/vincenzodr/Time-Series-Library
# %cd /kaggle/working/Time-Series-Library

# %% [markdown]
# ### Install requirements

# %%
# !pip install -r requirements.txt
# !pip install patool sktime reformer_pytorch

# %% [markdown]
# ## Training

# %%
# !python -u run.py \
  --task_name classification \
  --is_training 1 \
  --root_path /kaggle/input/gpvs-gan-dataset/gpvs_sl200_s15 \
  --model_id GPVS \
  --model TimesNet \
  --data GPVS \
  --e_layers 2 \
  --batch_size 16 \
  --d_model 64 \
  --d_ff 64 \
  --top_k 1 \
  --des 'Exp' \
  --itr 1 \
  --learning_rate 0.001 \
  --train_epochs 30 \
  --patience 3

# %% [markdown]
# ## Test

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sn
import matplotlib.pyplot as plt

# %% [markdown]
# ### Test results

# %%
df = pd.read_csv('/kaggle/working/Time-Series-Library/test.csv').T[1:]
class_names = ['F0L', 'F0M', 'F1L', 'F1M', 'F2L', 'F2M', 'F3L', 'F3M', 'F4L', 'F4M', 'F5L', 'F5M', 'F6L', 'F6M', 'F7L', 'F7M']

y_pred = df[0]
y_true = df[1]

# %%
np.mean(y_pred == y_true)

# %%
print(classification_report(y_true,y_pred, target_names = class_names))

# %%
c = confusion_matrix(y_true,y_pred)
df_cm = pd.DataFrame(c, index = class_names, columns = class_names)
plt.figure(figsize = (20,20))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
sn.heatmap(df_cm, annot=True)
